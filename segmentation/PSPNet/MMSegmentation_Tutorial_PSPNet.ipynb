# %% [markdown]
# # MMSegmentation Tutorial
# Welcome to MMSegmentation!
#
# In this tutorial, we demo
# * How to do inference with MMSeg trained weight
# * How to train on your own dataset and visualize the results.

# %%
cd mmsegmentation
# Out:
# /home/test/carasml/segmentation/PSPNet/mmsegmentation
# /home/test/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# Check Pytorch installation
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())

# Check MMSegmentation installation
import mmseg
print(mmseg.__version__)
# Out:
# 2.7.0+cu128 True
# 1.2.2

# %% [markdown]
# ## Finetune a semantic segmentation model on a new dataset
#
# To finetune on a customized dataset, the following steps are necessary.
# 1. Add a new dataset class.
# 2. Create a config file accordingly.
# 3. Perform training and evaluation.

# %% [markdown]
# ### Add a new dataset
#
# Datasets in MMSegmentation require image and semantic segmentation maps to be placed in folders with the same prefix. To support a new dataset, we may need to modify the original file structure.
#
# In this tutorial, we give an example of converting the dataset. You may refer to [docs](https://github.com/open-mmlab/mmsegmentation/blob/master/docs/en/tutorials/customize_datasets.md#customize-datasets-by-reorganizing-data) for details about dataset reorganization.
#
# We use [Stanford Background Dataset](http://dags.stanford.edu/projects/scenedataset.html) as an example. The dataset contains 715 images chosen from existing public datasets [LabelMe](http://labelme.csail.mit.edu), [MSRC](http://research.microsoft.com/en-us/projects/objectclassrecognition), [PASCAL VOC](http://pascallin.ecs.soton.ac.uk/challenges/VOC) and [Geometric Context](http://www.cs.illinois.edu/homes/dhoiem/). Images from these datasets are mainly outdoor scenes, each containing approximately 320-by-240 pixels.
# In this tutorial, we use the region annotations as labels. There are 8 classes in total, i.e. sky, tree, road, grass, water, building, mountain, and foreground object.
# The dataset should have been placed in the mmsegmentation folder, if not you can download with below code

# %% [markdown]
# The dataset should have been automatically downloaded and saved at mmsegmentation/, named iccv09Data <br>
# If you cannot find it, you can go to terminal and download it with the code <br>
# wget http://dags.stanford.edu/data/iccv09Data.tar.gz -O stanford_background.tar.gz  <br>
# tar xf stanford_background.tar.gz -C mmsegmentation  <br>

# %%
# dataset is not perfect, some pixels are unclassified and left as unknowns (class -1)
# we clean it by assigning unknowns as neighbour class, and drop sample if there are many unknowns
import os
import re
import numpy as np
from scipy import stats
from collections import Counter

def process_file(filepath):
    # Read matrix from file
    with open(filepath, 'r') as f:
        matrix = []
        for line in f:
            row = [float(x) for x in line.strip().split()]
            matrix.append(row)
    
    arr = np.array(matrix)
    total_values = arr.size
    negatives = arr[arr < 0]
    negative_count = len(negatives)
    
    # Case 1: More than 1% negatives - delete file
    if negative_count > 0.01 * total_values:
        os.remove(filepath)
        print(f"Deleted {filepath} ({negative_count/total_values:.2%} negatives)")
        return
    
    # Case 2: Few negatives - replace with mode of nearby values
    if negative_count > 0:
        print(f"Processing {filepath} ({negative_count} negatives)")
        rows, cols = arr.shape
        
        # Create padded array for edge handling
        padded = np.pad(arr, 1, mode='constant', constant_values=np.nan)
        
        for i in range(rows):
            for j in range(cols):
                if arr[i,j] < 0:
                    # Get 3x3 neighborhood (excluding current cell)
                    neighborhood = padded[i:i+3, j:j+3].flatten()
                    neighborhood = neighborhood[~np.isnan(neighborhood)]
                    neighborhood = neighborhood[neighborhood >= 0]  # Exclude other negatives
                    
                    if len(neighborhood) > 0:
                        # Calculate mode of positive neighbors
                        mode = stats.mode(neighborhood, keepdims=False).mode
                        arr[i,j] = mode
                    else:
                        # If no valid neighbors, use global mode
                        global_mode = stats.mode(arr[arr >= 0].flatten()).mode
                        arr[i,j] = global_mode
        
        # Save corrected file
        np.savetxt(filepath, arr, fmt='%.6f')
        print(f"Corrected {filepath}")

# Main processing
label_dir = "iccv09Data/labels/"
for filename in os.listdir(label_dir):
    if filename.endswith(".regions.txt"):
        filepath = os.path.join(label_dir, filename)
        process_file(filepath)
# Out:
# Processing iccv09Data/labels/4100246.regions.txt (12 negatives)
# Corrected iccv09Data/labels/4100246.regions.txt
# Deleted iccv09Data/labels/5000123.regions.txt (1.24% negatives)
# Processing iccv09Data/labels/6000192.regions.txt (3 negatives)
# Corrected iccv09Data/labels/6000192.regions.txt
# Processing iccv09Data/labels/6000205.regions.txt (55 negatives)
# Corrected iccv09Data/labels/6000205.regions.txt
# Processing iccv09Data/labels/0101801.regions.txt (4 negatives)
# Corrected iccv09Data/labels/0101801.regions.txt
# Processing iccv09Data/labels/6000296.regions.txt (19 negatives)
# Corrected iccv09Data/labels/6000296.regions.txt
# Processing iccv09Data/labels/9001619.regions.txt (75 negatives)
# Corrected iccv09Data/labels/9001619.regions.txt
# Processing iccv09Data/labels/0101060.regions.txt (3 negatives)
# Corrected iccv09Data/labels/0101060.regions.txt
# Processing iccv09Data/labels/1000351.regions.txt (19 negatives)
# Corrected iccv09Data/labels/1000351.regions.txt
# Processing iccv09Data/labels/6000083.regions.txt (63 negatives)
# Corrected iccv09Data/labels/6000083.regions.txt
# Processing iccv09Data/labels/9000127.regions.txt (4 negatives)
# Corrected iccv09Data/labels/9000127.regions.txt
# Processing iccv09Data/labels/6000023.regions.txt (221 negatives)
# Corrected iccv09Data/labels/6000023.regions.txt
# Processing iccv09Data/labels/6000225.regions.txt (15 negatives)
# Corrected iccv09Data/labels/6000225.regions.txt
# Processing iccv09Data/labels/1001944.regions.txt (1 negatives)
# Corrected iccv09Data/labels/1001944.regions.txt
# Deleted iccv09Data/labels/3001336.regions.txt (16.12% negatives)
# Processing iccv09Data/labels/0100579.regions.txt (18 negatives)
# Corrected iccv09Data/labels/0100579.regions.txt
# Processing iccv09Data/labels/0005633.regions.txt (1 negatives)
# Corrected iccv09Data/labels/0005633.regions.txt
# Processing iccv09Data/labels/6000191.regions.txt (23 negatives)
# Corrected iccv09Data/labels/6000191.regions.txt
# Processing iccv09Data/labels/6000035.regions.txt (6 negatives)
# Corrected iccv09Data/labels/6000035.regions.txt
# Processing iccv09Data/labels/1000105.regions.txt (4 negatives)
# Corrected iccv09Data/labels/1000105.regions.txt
# Deleted iccv09Data/labels/6000063.regions.txt (5.31% negatives)
# Processing iccv09Data/labels/1000875.regions.txt (21 negatives)
# Corrected iccv09Data/labels/1000875.regions.txt
# Processing iccv09Data/labels/0003178.regions.txt (12 negatives)
# Corrected iccv09Data/labels/0003178.regions.txt
# Processing iccv09Data/labels/2000042.regions.txt (3 negatives)
# Corrected iccv09Data/labels/2000042.regions.txt
# Processing iccv09Data/labels/6000046.regions.txt (3 negatives)
# Corrected iccv09Data/labels/6000046.regions.txt
# Deleted iccv09Data/labels/6000306.regions.txt (1.54% negatives)
# Processing iccv09Data/labels/3001131.regions.txt (1 negatives)
# Corrected iccv09Data/labels/3001131.regions.txt
# Processing iccv09Data/labels/6000058.regions.txt (149 negatives)
# Corrected iccv09Data/labels/6000058.regions.txt
# Deleted iccv09Data/labels/3002154.regions.txt (1.49% negatives)
# Deleted iccv09Data/labels/6000099.regions.txt (3.34% negatives)
# Processing iccv09Data/labels/6000233.regions.txt (241 negatives)
# Corrected iccv09Data/labels/6000233.regions.txt
# Processing iccv09Data/labels/1000947.regions.txt (3 negatives)
# Corrected iccv09Data/labels/1000947.regions.txt
# Processing iccv09Data/labels/5000120.regions.txt (34 negatives)
# Corrected iccv09Data/labels/5000120.regions.txt
# Processing iccv09Data/labels/6000158.regions.txt (7 negatives)
# Corrected iccv09Data/labels/6000158.regions.txt
# Processing iccv09Data/labels/1000061.regions.txt (3 negatives)
# Corrected iccv09Data/labels/1000061.regions.txt
# Processing iccv09Data/labels/5000226.regions.txt (2 negatives)
# Corrected iccv09Data/labels/5000226.regions.txt
# Processing iccv09Data/labels/3002221.regions.txt (2 negatives)
# Corrected iccv09Data/labels/3002221.regions.txt
# Processing iccv09Data/labels/6000279.regions.txt (31 negatives)
# Corrected iccv09Data/labels/6000279.regions.txt
# Processing iccv09Data/labels/6000074.regions.txt (5 negatives)
# Corrected iccv09Data/labels/6000074.regions.txt
# Processing iccv09Data/labels/5000162.regions.txt (1 negatives)
# Corrected iccv09Data/labels/5000162.regions.txt
# Processing iccv09Data/labels/6000016.regions.txt (35 negatives)
# Corrected iccv09Data/labels/6000016.regions.txt
# Processing iccv09Data/labels/0000382.regions.txt (172 negatives)
# Corrected iccv09Data/labels/0000382.regions.txt
# Processing iccv09Data/labels/1100023.regions.txt (7 negatives)
# Corrected iccv09Data/labels/1100023.regions.txt
# Processing iccv09Data/labels/0104552.regions.txt (1 negatives)
# Corrected iccv09Data/labels/0104552.regions.txt
# Processing iccv09Data/labels/0102534.regions.txt (2 negatives)
# Corrected iccv09Data/labels/0102534.regions.txt
# Processing iccv09Data/labels/5000265.regions.txt (2 negatives)
# Corrected iccv09Data/labels/5000265.regions.txt
# Processing iccv09Data/labels/6000160.regions.txt (13 negatives)
# Corrected iccv09Data/labels/6000160.regions.txt
# Deleted iccv09Data/labels/5000192.regions.txt (20.39% negatives)
# Processing iccv09Data/labels/6000291.regions.txt (17 negatives)
# Corrected iccv09Data/labels/6000291.regions.txt
# Processing iccv09Data/labels/0000051.regions.txt (15 negatives)
# Corrected iccv09Data/labels/0000051.regions.txt
# Processing iccv09Data/labels/6000330.regions.txt (8 negatives)
# Corrected iccv09Data/labels/6000330.regions.txt
# Deleted iccv09Data/labels/1000993.regions.txt (5.30% negatives)
# Processing iccv09Data/labels/6000290.regions.txt (71 negatives)
# Corrected iccv09Data/labels/6000290.regions.txt
# Processing iccv09Data/labels/5000016.regions.txt (3 negatives)
# Corrected iccv09Data/labels/5000016.regions.txt
# Processing iccv09Data/labels/0102403.regions.txt (3 negatives)
# Corrected iccv09Data/labels/0102403.regions.txt
# Deleted iccv09Data/labels/5000195.regions.txt (16.84% negatives)
# Processing iccv09Data/labels/6000308.regions.txt (109 negatives)
# Corrected iccv09Data/labels/6000308.regions.txt
# Processing iccv09Data/labels/2000023.regions.txt (4 negatives)
# Corrected iccv09Data/labels/2000023.regions.txt
# Processing iccv09Data/labels/6000295.regions.txt (10 negatives)
# Corrected iccv09Data/labels/6000295.regions.txt
# Processing iccv09Data/labels/6000300.regions.txt (9 negatives)
# Corrected iccv09Data/labels/6000300.regions.txt
# Deleted iccv09Data/labels/6000275.regions.txt (3.20% negatives)
# Processing iccv09Data/labels/6000196.regions.txt (3 negatives)
# Corrected iccv09Data/labels/6000196.regions.txt
# Processing iccv09Data/labels/6000174.regions.txt (2 negatives)
# Corrected iccv09Data/labels/6000174.regions.txt
# Processing iccv09Data/labels/6000267.regions.txt (39 negatives)
# Corrected iccv09Data/labels/6000267.regions.txt
# Processing iccv09Data/labels/6000156.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000156.regions.txt
# Processing iccv09Data/labels/9002021.regions.txt (271 negatives)
# Corrected iccv09Data/labels/9002021.regions.txt
# Processing iccv09Data/labels/6000189.regions.txt (12 negatives)
# Corrected iccv09Data/labels/6000189.regions.txt
# Processing iccv09Data/labels/6000284.regions.txt (73 negatives)
# Corrected iccv09Data/labels/6000284.regions.txt
# Deleted iccv09Data/labels/1001252.regions.txt (7.18% negatives)
# Processing iccv09Data/labels/0004069.regions.txt (126 negatives)
# Corrected iccv09Data/labels/0004069.regions.txt
# Processing iccv09Data/labels/6000151.regions.txt (499 negatives)
# Corrected iccv09Data/labels/6000151.regions.txt
# Processing iccv09Data/labels/6000288.regions.txt (532 negatives)
# Corrected iccv09Data/labels/6000288.regions.txt
# Processing iccv09Data/labels/6000054.regions.txt (123 negatives)
# Corrected iccv09Data/labels/6000054.regions.txt
# Deleted iccv09Data/labels/1001794.regions.txt (3.27% negatives)
# Processing iccv09Data/labels/5000127.regions.txt (8 negatives)
# Corrected iccv09Data/labels/5000127.regions.txt
# Processing iccv09Data/labels/6000274.regions.txt (187 negatives)
# Corrected iccv09Data/labels/6000274.regions.txt
# Processing iccv09Data/labels/6000184.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000184.regions.txt
# Processing iccv09Data/labels/1000097.regions.txt (9 negatives)
# Corrected iccv09Data/labels/1000097.regions.txt
# Processing iccv09Data/labels/6000259.regions.txt (5 negatives)
# Corrected iccv09Data/labels/6000259.regions.txt
# Processing iccv09Data/labels/6000350.regions.txt (9 negatives)
# Corrected iccv09Data/labels/6000350.regions.txt
# Processing iccv09Data/labels/3001230.regions.txt (53 negatives)
# Corrected iccv09Data/labels/3001230.regions.txt
# Processing iccv09Data/labels/6000102.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000102.regions.txt
# Processing iccv09Data/labels/0002395.regions.txt (2 negatives)
# Corrected iccv09Data/labels/0002395.regions.txt
# Processing iccv09Data/labels/6000036.regions.txt (289 negatives)
# Corrected iccv09Data/labels/6000036.regions.txt
# Processing iccv09Data/labels/6000210.regions.txt (3 negatives)
# Corrected iccv09Data/labels/6000210.regions.txt
# Processing iccv09Data/labels/6000281.regions.txt (147 negatives)
# Corrected iccv09Data/labels/6000281.regions.txt
# Processing iccv09Data/labels/6000277.regions.txt (27 negatives)
# Corrected iccv09Data/labels/6000277.regions.txt
# Processing iccv09Data/labels/6000048.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000048.regions.txt
# Processing iccv09Data/labels/6000087.regions.txt (5 negatives)
# Corrected iccv09Data/labels/6000087.regions.txt
# Processing iccv09Data/labels/6000240.regions.txt (14 negatives)
# Corrected iccv09Data/labels/6000240.regions.txt
# Processing iccv09Data/labels/0105146.regions.txt (1 negatives)
# Corrected iccv09Data/labels/0105146.regions.txt
# Deleted iccv09Data/labels/0101488.regions.txt (2.05% negatives)
# Processing iccv09Data/labels/1001195.regions.txt (1 negatives)
# Corrected iccv09Data/labels/1001195.regions.txt
# Processing iccv09Data/labels/5000132.regions.txt (82 negatives)
# Corrected iccv09Data/labels/5000132.regions.txt
# Processing iccv09Data/labels/6000165.regions.txt (51 negatives)
# Corrected iccv09Data/labels/6000165.regions.txt
# Processing iccv09Data/labels/6000000.regions.txt (2 negatives)
# Corrected iccv09Data/labels/6000000.regions.txt
# Processing iccv09Data/labels/0100241.regions.txt (8 negatives)
# Corrected iccv09Data/labels/0100241.regions.txt
# Processing iccv09Data/labels/5000122.regions.txt (2 negatives)
# Corrected iccv09Data/labels/5000122.regions.txt
# Deleted iccv09Data/labels/3003448.regions.txt (5.13% negatives)
# Processing iccv09Data/labels/6000110.regions.txt (101 negatives)
# Corrected iccv09Data/labels/6000110.regions.txt
# Processing iccv09Data/labels/6000221.regions.txt (87 negatives)
# Corrected iccv09Data/labels/6000221.regions.txt
# Processing iccv09Data/labels/6000050.regions.txt (5 negatives)
# Corrected iccv09Data/labels/6000050.regions.txt
# Processing iccv09Data/labels/6000114.regions.txt (34 negatives)
# Corrected iccv09Data/labels/6000114.regions.txt
# Processing iccv09Data/labels/6000177.regions.txt (31 negatives)
# Corrected iccv09Data/labels/6000177.regions.txt
# Processing iccv09Data/labels/0100164.regions.txt (6 negatives)
# Corrected iccv09Data/labels/0100164.regions.txt
# Processing iccv09Data/labels/6000237.regions.txt (5 negatives)
# Corrected iccv09Data/labels/6000237.regions.txt
# Processing iccv09Data/labels/5000197.regions.txt (2 negatives)
# Corrected iccv09Data/labels/5000197.regions.txt
# Processing iccv09Data/labels/0100822.regions.txt (6 negatives)
# Corrected iccv09Data/labels/0100822.regions.txt
# Processing iccv09Data/labels/6000243.regions.txt (52 negatives)
# Corrected iccv09Data/labels/6000243.regions.txt
# Processing iccv09Data/labels/6000206.regions.txt (3 negatives)
# Corrected iccv09Data/labels/6000206.regions.txt
# Processing iccv09Data/labels/3002411.regions.txt (1 negatives)
# Corrected iccv09Data/labels/3002411.regions.txt
# Processing iccv09Data/labels/6000194.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000194.regions.txt
# Processing iccv09Data/labels/6000209.regions.txt (27 negatives)
# Corrected iccv09Data/labels/6000209.regions.txt
# Deleted iccv09Data/labels/3000323.regions.txt (1.24% negatives)
# Processing iccv09Data/labels/6000173.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000173.regions.txt
# Processing iccv09Data/labels/6000107.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000107.regions.txt
# Processing iccv09Data/labels/6000269.regions.txt (69 negatives)
# Corrected iccv09Data/labels/6000269.regions.txt
# Processing iccv09Data/labels/6000013.regions.txt (93 negatives)
# Corrected iccv09Data/labels/6000013.regions.txt
# Processing iccv09Data/labels/5000181.regions.txt (2 negatives)
# Corrected iccv09Data/labels/5000181.regions.txt
# Processing iccv09Data/labels/6000276.regions.txt (49 negatives)
# Corrected iccv09Data/labels/6000276.regions.txt
# Deleted iccv09Data/labels/2000031.regions.txt (2.80% negatives)
# Deleted iccv09Data/labels/3001421.regions.txt (18.46% negatives)
# Deleted iccv09Data/labels/0105003.regions.txt (3.51% negatives)
# Processing iccv09Data/labels/6000204.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000204.regions.txt
# Processing iccv09Data/labels/6000009.regions.txt (2 negatives)
# Corrected iccv09Data/labels/6000009.regions.txt
# Processing iccv09Data/labels/6000335.regions.txt (4 negatives)
# Corrected iccv09Data/labels/6000335.regions.txt
# Processing iccv09Data/labels/3002059.regions.txt (3 negatives)
# Corrected iccv09Data/labels/3002059.regions.txt
# Deleted iccv09Data/labels/5000200.regions.txt (3.56% negatives)
# Processing iccv09Data/labels/6000186.regions.txt (127 negatives)
# Corrected iccv09Data/labels/6000186.regions.txt
# Processing iccv09Data/labels/6000195.regions.txt (19 negatives)
# Corrected iccv09Data/labels/6000195.regions.txt
# Processing iccv09Data/labels/6000119.regions.txt (645 negatives)
# Corrected iccv09Data/labels/6000119.regions.txt
# Processing iccv09Data/labels/8003952.regions.txt (1 negatives)
# Corrected iccv09Data/labels/8003952.regions.txt
# Processing iccv09Data/labels/6000021.regions.txt (184 negatives)
# Corrected iccv09Data/labels/6000021.regions.txt
# Processing iccv09Data/labels/6000293.regions.txt (13 negatives)
# Corrected iccv09Data/labels/6000293.regions.txt
# Processing iccv09Data/labels/6000004.regions.txt (10 negatives)
# Corrected iccv09Data/labels/6000004.regions.txt
# Processing iccv09Data/labels/6000101.regions.txt (61 negatives)
# Corrected iccv09Data/labels/6000101.regions.txt
# Processing iccv09Data/labels/6000220.regions.txt (131 negatives)
# Corrected iccv09Data/labels/6000220.regions.txt
# Processing iccv09Data/labels/6000307.regions.txt (153 negatives)
# Corrected iccv09Data/labels/6000307.regions.txt
# Processing iccv09Data/labels/0001677.regions.txt (1 negatives)
# Corrected iccv09Data/labels/0001677.regions.txt
# Processing iccv09Data/labels/6000257.regions.txt (69 negatives)
# Corrected iccv09Data/labels/6000257.regions.txt
# Processing iccv09Data/labels/3000945.regions.txt (1 negatives)
# Corrected iccv09Data/labels/3000945.regions.txt
# Processing iccv09Data/labels/0000952.regions.txt (3 negatives)
# Corrected iccv09Data/labels/0000952.regions.txt
# Processing iccv09Data/labels/6000062.regions.txt (430 negatives)
# Corrected iccv09Data/labels/6000062.regions.txt
# Processing iccv09Data/labels/0003463.regions.txt (82 negatives)
# Corrected iccv09Data/labels/0003463.regions.txt
# Processing iccv09Data/labels/6000131.regions.txt (120 negatives)
# Corrected iccv09Data/labels/6000131.regions.txt
# Processing iccv09Data/labels/6000343.regions.txt (2 negatives)
# Corrected iccv09Data/labels/6000343.regions.txt
# Processing iccv09Data/labels/0100030.regions.txt (1 negatives)
# Corrected iccv09Data/labels/0100030.regions.txt
# Processing iccv09Data/labels/6000094.regions.txt (24 negatives)
# Corrected iccv09Data/labels/6000094.regions.txt
# Processing iccv09Data/labels/5000119.regions.txt (39 negatives)
# Corrected iccv09Data/labels/5000119.regions.txt
# Processing iccv09Data/labels/6000104.regions.txt (21 negatives)
# Corrected iccv09Data/labels/6000104.regions.txt
# Processing iccv09Data/labels/6000025.regions.txt (358 negatives)
# Corrected iccv09Data/labels/6000025.regions.txt
# Processing iccv09Data/labels/0104808.regions.txt (1 negatives)
# Corrected iccv09Data/labels/0104808.regions.txt
# Deleted iccv09Data/labels/3003328.regions.txt (16.55% negatives)
# Processing iccv09Data/labels/2000032.regions.txt (11 negatives)
# Corrected iccv09Data/labels/2000032.regions.txt
# Processing iccv09Data/labels/6000007.regions.txt (64 negatives)
# Corrected iccv09Data/labels/6000007.regions.txt
# Processing iccv09Data/labels/6000258.regions.txt (196 negatives)
# Corrected iccv09Data/labels/6000258.regions.txt
# Processing iccv09Data/labels/1100016.regions.txt (1 negatives)
# Corrected iccv09Data/labels/1100016.regions.txt
# Processing iccv09Data/labels/6000347.regions.txt (2 negatives)
# Corrected iccv09Data/labels/6000347.regions.txt
# Processing iccv09Data/labels/6000108.regions.txt (10 negatives)
# Corrected iccv09Data/labels/6000108.regions.txt
# Processing iccv09Data/labels/6000053.regions.txt (13 negatives)
# Corrected iccv09Data/labels/6000053.regions.txt
# Processing iccv09Data/labels/6000112.regions.txt (2 negatives)
# Corrected iccv09Data/labels/6000112.regions.txt
# Processing iccv09Data/labels/5000147.regions.txt (10 negatives)
# Corrected iccv09Data/labels/5000147.regions.txt
# Processing iccv09Data/labels/0101434.regions.txt (12 negatives)
# Corrected iccv09Data/labels/0101434.regions.txt
# Processing iccv09Data/labels/6000014.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000014.regions.txt
# Processing iccv09Data/labels/4100066.regions.txt (77 negatives)
# Corrected iccv09Data/labels/4100066.regions.txt
# Processing iccv09Data/labels/6000010.regions.txt (367 negatives)
# Corrected iccv09Data/labels/6000010.regions.txt
# Processing iccv09Data/labels/1100031.regions.txt (9 negatives)
# Corrected iccv09Data/labels/1100031.regions.txt
# Processing iccv09Data/labels/5000191.regions.txt (2 negatives)
# Corrected iccv09Data/labels/5000191.regions.txt
# Processing iccv09Data/labels/1000580.regions.txt (1 negatives)
# Corrected iccv09Data/labels/1000580.regions.txt
# Processing iccv09Data/labels/0102566.regions.txt (14 negatives)
# Corrected iccv09Data/labels/0102566.regions.txt
# Processing iccv09Data/labels/6000217.regions.txt (69 negatives)
# Corrected iccv09Data/labels/6000217.regions.txt
# Deleted iccv09Data/labels/2000043.regions.txt (16.64% negatives)
# Processing iccv09Data/labels/6000256.regions.txt (15 negatives)
# Corrected iccv09Data/labels/6000256.regions.txt
# Processing iccv09Data/labels/6000143.regions.txt (761 negatives)
# Corrected iccv09Data/labels/6000143.regions.txt
# Processing iccv09Data/labels/9000029.regions.txt (2 negatives)
# Corrected iccv09Data/labels/9000029.regions.txt
# Processing iccv09Data/labels/6000144.regions.txt (8 negatives)
# Corrected iccv09Data/labels/6000144.regions.txt
# Processing iccv09Data/labels/0002136.regions.txt (166 negatives)
# Corrected iccv09Data/labels/0002136.regions.txt
# Deleted iccv09Data/labels/3002594.regions.txt (22.07% negatives)
# Processing iccv09Data/labels/6000299.regions.txt (5 negatives)
# Corrected iccv09Data/labels/6000299.regions.txt
# Deleted iccv09Data/labels/2000044.regions.txt (2.31% negatives)
# Processing iccv09Data/labels/2000004.regions.txt (6 negatives)
# Corrected iccv09Data/labels/2000004.regions.txt
# Processing iccv09Data/labels/3001018.regions.txt (13 negatives)
# Corrected iccv09Data/labels/3001018.regions.txt
# Processing iccv09Data/labels/6000250.regions.txt (404 negatives)
# Corrected iccv09Data/labels/6000250.regions.txt
# Processing iccv09Data/labels/6000202.regions.txt (49 negatives)
# Corrected iccv09Data/labels/6000202.regions.txt
# Processing iccv09Data/labels/6000315.regions.txt (3 negatives)
# Corrected iccv09Data/labels/6000315.regions.txt
# Processing iccv09Data/labels/6000072.regions.txt (2 negatives)
# Corrected iccv09Data/labels/6000072.regions.txt
# Processing iccv09Data/labels/0003793.regions.txt (33 negatives)
# Corrected iccv09Data/labels/0003793.regions.txt
# Processing iccv09Data/labels/6000345.regions.txt (40 negatives)
# Corrected iccv09Data/labels/6000345.regions.txt
# Processing iccv09Data/labels/6000126.regions.txt (7 negatives)
# Corrected iccv09Data/labels/6000126.regions.txt
# Deleted iccv09Data/labels/3003731.regions.txt (10.24% negatives)
# Processing iccv09Data/labels/6000301.regions.txt (4 negatives)
# Corrected iccv09Data/labels/6000301.regions.txt
# Processing iccv09Data/labels/6000273.regions.txt (2 negatives)
# Corrected iccv09Data/labels/6000273.regions.txt
# Processing iccv09Data/labels/6000253.regions.txt (122 negatives)
# Corrected iccv09Data/labels/6000253.regions.txt
# Processing iccv09Data/labels/6000325.regions.txt (328 negatives)
# Corrected iccv09Data/labels/6000325.regions.txt
# Processing iccv09Data/labels/2000001.regions.txt (3 negatives)
# Corrected iccv09Data/labels/2000001.regions.txt
# Processing iccv09Data/labels/5000173.regions.txt (4 negatives)
# Corrected iccv09Data/labels/5000173.regions.txt
# Processing iccv09Data/labels/6000201.regions.txt (50 negatives)
# Corrected iccv09Data/labels/6000201.regions.txt
# Processing iccv09Data/labels/6000312.regions.txt (218 negatives)
# Corrected iccv09Data/labels/6000312.regions.txt
# Processing iccv09Data/labels/6000238.regions.txt (83 negatives)
# Corrected iccv09Data/labels/6000238.regions.txt
# Processing iccv09Data/labels/6000214.regions.txt (8 negatives)
# Corrected iccv09Data/labels/6000214.regions.txt
# Processing iccv09Data/labels/6000135.regions.txt (41 negatives)
# Corrected iccv09Data/labels/6000135.regions.txt
# Processing iccv09Data/labels/6000059.regions.txt (24 negatives)
# Corrected iccv09Data/labels/6000059.regions.txt
# Processing iccv09Data/labels/6000175.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000175.regions.txt
# Deleted iccv09Data/labels/6000066.regions.txt (2.05% negatives)
# Processing iccv09Data/labels/6000079.regions.txt (102 negatives)
# Corrected iccv09Data/labels/6000079.regions.txt
# Processing iccv09Data/labels/6000122.regions.txt (7 negatives)
# Corrected iccv09Data/labels/6000122.regions.txt
# Processing iccv09Data/labels/2000039.regions.txt (642 negatives)
# Corrected iccv09Data/labels/2000039.regions.txt
# Processing iccv09Data/labels/6000181.regions.txt (6 negatives)
# Corrected iccv09Data/labels/6000181.regions.txt
# Deleted iccv09Data/labels/0105064.regions.txt (6.03% negatives)
# Processing iccv09Data/labels/0100061.regions.txt (22 negatives)
# Corrected iccv09Data/labels/0100061.regions.txt
# Processing iccv09Data/labels/1100017.regions.txt (5 negatives)
# Corrected iccv09Data/labels/1100017.regions.txt
# Processing iccv09Data/labels/6000167.regions.txt (190 negatives)
# Corrected iccv09Data/labels/6000167.regions.txt
# Processing iccv09Data/labels/0102170.regions.txt (11 negatives)
# Corrected iccv09Data/labels/0102170.regions.txt
# Processing iccv09Data/labels/0102039.regions.txt (70 negatives)
# Corrected iccv09Data/labels/0102039.regions.txt
# Processing iccv09Data/labels/6000283.regions.txt (212 negatives)
# Corrected iccv09Data/labels/6000283.regions.txt
# Deleted iccv09Data/labels/0100787.regions.txt (3.51% negatives)
# Processing iccv09Data/labels/6000103.regions.txt (7 negatives)
# Corrected iccv09Data/labels/6000103.regions.txt
# Processing iccv09Data/labels/3003791.regions.txt (1 negatives)
# Corrected iccv09Data/labels/3003791.regions.txt
# Processing iccv09Data/labels/6000157.regions.txt (5 negatives)
# Corrected iccv09Data/labels/6000157.regions.txt
# Processing iccv09Data/labels/1000615.regions.txt (2 negatives)
# Corrected iccv09Data/labels/1000615.regions.txt
# Processing iccv09Data/labels/6000278.regions.txt (43 negatives)
# Corrected iccv09Data/labels/6000278.regions.txt
# Processing iccv09Data/labels/6000190.regions.txt (30 negatives)
# Corrected iccv09Data/labels/6000190.regions.txt
# Processing iccv09Data/labels/6000263.regions.txt (43 negatives)
# Corrected iccv09Data/labels/6000263.regions.txt
# Processing iccv09Data/labels/6000327.regions.txt (21 negatives)
# Corrected iccv09Data/labels/6000327.regions.txt
# Processing iccv09Data/labels/6000241.regions.txt (25 negatives)
# Corrected iccv09Data/labels/6000241.regions.txt
# Processing iccv09Data/labels/6000332.regions.txt (559 negatives)
# Corrected iccv09Data/labels/6000332.regions.txt
# Processing iccv09Data/labels/6000092.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000092.regions.txt
# Processing iccv09Data/labels/6000081.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000081.regions.txt
# Processing iccv09Data/labels/2000008.regions.txt (1 negatives)
# Corrected iccv09Data/labels/2000008.regions.txt
# Processing iccv09Data/labels/6000113.regions.txt (213 negatives)
# Corrected iccv09Data/labels/6000113.regions.txt
# Processing iccv09Data/labels/6000163.regions.txt (271 negatives)
# Corrected iccv09Data/labels/6000163.regions.txt
# Deleted iccv09Data/labels/6000298.regions.txt (1.12% negatives)
# Processing iccv09Data/labels/5000129.regions.txt (4 negatives)
# Corrected iccv09Data/labels/5000129.regions.txt
# Processing iccv09Data/labels/6000292.regions.txt (65 negatives)
# Corrected iccv09Data/labels/6000292.regions.txt
# Processing iccv09Data/labels/6000105.regions.txt (13 negatives)
# Corrected iccv09Data/labels/6000105.regions.txt
# Processing iccv09Data/labels/5000133.regions.txt (9 negatives)
# Corrected iccv09Data/labels/5000133.regions.txt
# Processing iccv09Data/labels/1100029.regions.txt (15 negatives)
# Corrected iccv09Data/labels/1100029.regions.txt
# Processing iccv09Data/labels/9000868.regions.txt (148 negatives)
# Corrected iccv09Data/labels/9000868.regions.txt
# Processing iccv09Data/labels/6000003.regions.txt (83 negatives)
# Corrected iccv09Data/labels/6000003.regions.txt
# Deleted iccv09Data/labels/3001004.regions.txt (12.28% negatives)
# Processing iccv09Data/labels/6000198.regions.txt (2 negatives)
# Corrected iccv09Data/labels/6000198.regions.txt
# Processing iccv09Data/labels/8005616.regions.txt (76 negatives)
# Corrected iccv09Data/labels/8005616.regions.txt
# Processing iccv09Data/labels/6000076.regions.txt (5 negatives)
# Corrected iccv09Data/labels/6000076.regions.txt
# Processing iccv09Data/labels/5000149.regions.txt (3 negatives)
# Corrected iccv09Data/labels/5000149.regions.txt
# Processing iccv09Data/labels/6000322.regions.txt (3 negatives)
# Corrected iccv09Data/labels/6000322.regions.txt
# Processing iccv09Data/labels/0003728.regions.txt (15 negatives)
# Corrected iccv09Data/labels/0003728.regions.txt
# Processing iccv09Data/labels/6000176.regions.txt (46 negatives)
# Corrected iccv09Data/labels/6000176.regions.txt
# Processing iccv09Data/labels/6000354.regions.txt (2 negatives)
# Corrected iccv09Data/labels/6000354.regions.txt
# Processing iccv09Data/labels/6000082.regions.txt (5 negatives)
# Corrected iccv09Data/labels/6000082.regions.txt
# Processing iccv09Data/labels/6000227.regions.txt (32 negatives)
# Corrected iccv09Data/labels/6000227.regions.txt
# Processing iccv09Data/labels/6000002.regions.txt (44 negatives)
# Corrected iccv09Data/labels/6000002.regions.txt
# Deleted iccv09Data/labels/6000340.regions.txt (1.09% negatives)
# Deleted iccv09Data/labels/6000235.regions.txt (1.13% negatives)
# Processing iccv09Data/labels/6000305.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000305.regions.txt
# Processing iccv09Data/labels/0004498.regions.txt (3 negatives)
# Corrected iccv09Data/labels/0004498.regions.txt
# Processing iccv09Data/labels/6000022.regions.txt (35 negatives)
# Corrected iccv09Data/labels/6000022.regions.txt
# Processing iccv09Data/labels/6000185.regions.txt (124 negatives)
# Corrected iccv09Data/labels/6000185.regions.txt
# Processing iccv09Data/labels/6000164.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000164.regions.txt
# Processing iccv09Data/labels/6000150.regions.txt (404 negatives)
# Corrected iccv09Data/labels/6000150.regions.txt
# Processing iccv09Data/labels/5000150.regions.txt (26 negatives)
# Corrected iccv09Data/labels/5000150.regions.txt
# Processing iccv09Data/labels/6000339.regions.txt (306 negatives)
# Corrected iccv09Data/labels/6000339.regions.txt
# Processing iccv09Data/labels/3003322.regions.txt (7 negatives)
# Corrected iccv09Data/labels/3003322.regions.txt
# Processing iccv09Data/labels/3002206.regions.txt (13 negatives)
# Corrected iccv09Data/labels/3002206.regions.txt
# Processing iccv09Data/labels/5000126.regions.txt (5 negatives)
# Corrected iccv09Data/labels/5000126.regions.txt
# Processing iccv09Data/labels/6000353.regions.txt (34 negatives)
# Corrected iccv09Data/labels/6000353.regions.txt
# Processing iccv09Data/labels/6000323.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000323.regions.txt
# Processing iccv09Data/labels/4100280.regions.txt (27 negatives)
# Corrected iccv09Data/labels/4100280.regions.txt
# Processing iccv09Data/labels/6000352.regions.txt (158 negatives)
# Corrected iccv09Data/labels/6000352.regions.txt
# Processing iccv09Data/labels/6000336.regions.txt (9 negatives)
# Corrected iccv09Data/labels/6000336.regions.txt
# Processing iccv09Data/labels/6000179.regions.txt (394 negatives)
# Corrected iccv09Data/labels/6000179.regions.txt
# Deleted iccv09Data/labels/6000265.regions.txt (1.48% negatives)
# Processing iccv09Data/labels/6000145.regions.txt (49 negatives)
# Corrected iccv09Data/labels/6000145.regions.txt
# Processing iccv09Data/labels/6000134.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000134.regions.txt
# Processing iccv09Data/labels/6000039.regions.txt (8 negatives)
# Corrected iccv09Data/labels/6000039.regions.txt
# Processing iccv09Data/labels/6000268.regions.txt (4 negatives)
# Corrected iccv09Data/labels/6000268.regions.txt
# Processing iccv09Data/labels/6000338.regions.txt (6 negatives)
# Corrected iccv09Data/labels/6000338.regions.txt
# Processing iccv09Data/labels/3001555.regions.txt (3 negatives)
# Corrected iccv09Data/labels/3001555.regions.txt
# Processing iccv09Data/labels/9000395.regions.txt (275 negatives)
# Corrected iccv09Data/labels/9000395.regions.txt
# Processing iccv09Data/labels/6000061.regions.txt (70 negatives)
# Corrected iccv09Data/labels/6000061.regions.txt
# Processing iccv09Data/labels/6000254.regions.txt (514 negatives)
# Corrected iccv09Data/labels/6000254.regions.txt
# Processing iccv09Data/labels/5000234.regions.txt (1 negatives)
# Corrected iccv09Data/labels/5000234.regions.txt
# Processing iccv09Data/labels/6000049.regions.txt (4 negatives)
# Corrected iccv09Data/labels/6000049.regions.txt
# Processing iccv09Data/labels/6000355.regions.txt (7 negatives)
# Corrected iccv09Data/labels/6000355.regions.txt
# Processing iccv09Data/labels/6000011.regions.txt (22 negatives)
# Corrected iccv09Data/labels/6000011.regions.txt
# Processing iccv09Data/labels/0105305.regions.txt (1 negatives)
# Corrected iccv09Data/labels/0105305.regions.txt
# Processing iccv09Data/labels/6000228.regions.txt (149 negatives)
# Corrected iccv09Data/labels/6000228.regions.txt
# Processing iccv09Data/labels/1001875.regions.txt (1 negatives)
# Corrected iccv09Data/labels/1001875.regions.txt
# Processing iccv09Data/labels/6000027.regions.txt (251 negatives)
# Corrected iccv09Data/labels/6000027.regions.txt
# Processing iccv09Data/labels/6000316.regions.txt (4 negatives)
# Corrected iccv09Data/labels/6000316.regions.txt
# Processing iccv09Data/labels/6000346.regions.txt (3 negatives)
# Corrected iccv09Data/labels/6000346.regions.txt
# Processing iccv09Data/labels/6000034.regions.txt (7 negatives)
# Corrected iccv09Data/labels/6000034.regions.txt
# Processing iccv09Data/labels/5000125.regions.txt (1 negatives)
# Corrected iccv09Data/labels/5000125.regions.txt
# Processing iccv09Data/labels/6000207.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000207.regions.txt
# Processing iccv09Data/labels/6000326.regions.txt (3 negatives)
# Corrected iccv09Data/labels/6000326.regions.txt
# Processing iccv09Data/labels/6000211.regions.txt (15 negatives)
# Corrected iccv09Data/labels/6000211.regions.txt
# Processing iccv09Data/labels/2000037.regions.txt (7 negatives)
# Corrected iccv09Data/labels/2000037.regions.txt
# Processing iccv09Data/labels/9000989.regions.txt (3 negatives)
# Corrected iccv09Data/labels/9000989.regions.txt
# Processing iccv09Data/labels/6000095.regions.txt (48 negatives)
# Corrected iccv09Data/labels/6000095.regions.txt
# Deleted iccv09Data/labels/0000794.regions.txt (4.45% negatives)
# Processing iccv09Data/labels/6000342.regions.txt (53 negatives)
# Corrected iccv09Data/labels/6000342.regions.txt
# Processing iccv09Data/labels/6000333.regions.txt (97 negatives)
# Corrected iccv09Data/labels/6000333.regions.txt
# Deleted iccv09Data/labels/0103256.regions.txt (3.51% negatives)
# Processing iccv09Data/labels/5000130.regions.txt (27 negatives)
# Corrected iccv09Data/labels/5000130.regions.txt
# Processing iccv09Data/labels/6000086.regions.txt (159 negatives)
# Corrected iccv09Data/labels/6000086.regions.txt
# Processing iccv09Data/labels/5000183.regions.txt (1 negatives)
# Corrected iccv09Data/labels/5000183.regions.txt
# Deleted iccv09Data/labels/2000033.regions.txt (65.56% negatives)
# Deleted iccv09Data/labels/0006575.regions.txt (6.85% negatives)
# Deleted iccv09Data/labels/0100132.regions.txt (4.38% negatives)
# Processing iccv09Data/labels/6000161.regions.txt (56 negatives)
# Corrected iccv09Data/labels/6000161.regions.txt
# Processing iccv09Data/labels/6000037.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000037.regions.txt
# Processing iccv09Data/labels/6000026.regions.txt (192 negatives)
# Corrected iccv09Data/labels/6000026.regions.txt
# Processing iccv09Data/labels/0104194.regions.txt (6 negatives)
# Corrected iccv09Data/labels/0104194.regions.txt
# Processing iccv09Data/labels/6000090.regions.txt (10 negatives)
# Corrected iccv09Data/labels/6000090.regions.txt
# Processing iccv09Data/labels/6000154.regions.txt (5 negatives)
# Corrected iccv09Data/labels/6000154.regions.txt
# Processing iccv09Data/labels/6000222.regions.txt (9 negatives)
# Corrected iccv09Data/labels/6000222.regions.txt
# Processing iccv09Data/labels/6000064.regions.txt (6 negatives)
# Corrected iccv09Data/labels/6000064.regions.txt
# Processing iccv09Data/labels/5000121.regions.txt (2 negatives)
# Corrected iccv09Data/labels/5000121.regions.txt
# Processing iccv09Data/labels/6000348.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000348.regions.txt
# Processing iccv09Data/labels/1000882.regions.txt (1 negatives)
# Corrected iccv09Data/labels/1000882.regions.txt
# Processing iccv09Data/labels/5000202.regions.txt (1 negatives)
# Corrected iccv09Data/labels/5000202.regions.txt
# Processing iccv09Data/labels/6000138.regions.txt (90 negatives)
# Corrected iccv09Data/labels/6000138.regions.txt
# Processing iccv09Data/labels/6000261.regions.txt (41 negatives)
# Corrected iccv09Data/labels/6000261.regions.txt
# Processing iccv09Data/labels/4000086.regions.txt (2 negatives)
# Corrected iccv09Data/labels/4000086.regions.txt
# Processing iccv09Data/labels/0104958.regions.txt (4 negatives)
# Corrected iccv09Data/labels/0104958.regions.txt
# Processing iccv09Data/labels/6000270.regions.txt (2 negatives)
# Corrected iccv09Data/labels/6000270.regions.txt
# Deleted iccv09Data/labels/0103344.regions.txt (4.57% negatives)
# Processing iccv09Data/labels/3000759.regions.txt (4 negatives)
# Corrected iccv09Data/labels/3000759.regions.txt
# Processing iccv09Data/labels/0100851.regions.txt (2 negatives)
# Corrected iccv09Data/labels/0100851.regions.txt
# Deleted iccv09Data/labels/6000137.regions.txt (1.55% negatives)
# Processing iccv09Data/labels/6000329.regions.txt (2 negatives)
# Corrected iccv09Data/labels/6000329.regions.txt
# Processing iccv09Data/labels/6000038.regions.txt (24 negatives)
# Corrected iccv09Data/labels/6000038.regions.txt
# Processing iccv09Data/labels/6000109.regions.txt (3 negatives)
# Corrected iccv09Data/labels/6000109.regions.txt
# Processing iccv09Data/labels/6000065.regions.txt (4 negatives)
# Corrected iccv09Data/labels/6000065.regions.txt
# Processing iccv09Data/labels/5000172.regions.txt (1 negatives)
# Corrected iccv09Data/labels/5000172.regions.txt
# Deleted iccv09Data/labels/6000313.regions.txt (12.49% negatives)
# Processing iccv09Data/labels/6000132.regions.txt (6 negatives)
# Corrected iccv09Data/labels/6000132.regions.txt
# Processing iccv09Data/labels/8003836.regions.txt (81 negatives)
# Corrected iccv09Data/labels/8003836.regions.txt
# Processing iccv09Data/labels/6000230.regions.txt (61 negatives)
# Corrected iccv09Data/labels/6000230.regions.txt
# Deleted iccv09Data/labels/3001061.regions.txt (1.33% negatives)
# Processing iccv09Data/labels/6000226.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000226.regions.txt
# Processing iccv09Data/labels/6000218.regions.txt (29 negatives)
# Corrected iccv09Data/labels/6000218.regions.txt
# Processing iccv09Data/labels/2000034.regions.txt (1 negatives)
# Corrected iccv09Data/labels/2000034.regions.txt
# Processing iccv09Data/labels/2000035.regions.txt (1 negatives)
# Corrected iccv09Data/labels/2000035.regions.txt
# Processing iccv09Data/labels/6000051.regions.txt (448 negatives)
# Corrected iccv09Data/labels/6000051.regions.txt
# Processing iccv09Data/labels/6000297.regions.txt (2 negatives)
# Corrected iccv09Data/labels/6000297.regions.txt
# Processing iccv09Data/labels/6000271.regions.txt (22 negatives)
# Corrected iccv09Data/labels/6000271.regions.txt
# Processing iccv09Data/labels/6000310.regions.txt (3 negatives)
# Corrected iccv09Data/labels/6000310.regions.txt
# Processing iccv09Data/labels/1100003.regions.txt (3 negatives)
# Corrected iccv09Data/labels/1100003.regions.txt
# Processing iccv09Data/labels/6000280.regions.txt (100 negatives)
# Corrected iccv09Data/labels/6000280.regions.txt
# Processing iccv09Data/labels/6000069.regions.txt (107 negatives)
# Corrected iccv09Data/labels/6000069.regions.txt
# Processing iccv09Data/labels/6000244.regions.txt (110 negatives)
# Corrected iccv09Data/labels/6000244.regions.txt
# Processing iccv09Data/labels/0105159.regions.txt (1 negatives)
# Corrected iccv09Data/labels/0105159.regions.txt
# Processing iccv09Data/labels/6000219.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000219.regions.txt
# Processing iccv09Data/labels/6000015.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000015.regions.txt
# Processing iccv09Data/labels/1001688.regions.txt (4 negatives)
# Corrected iccv09Data/labels/1001688.regions.txt
# Processing iccv09Data/labels/6000091.regions.txt (2 negatives)
# Corrected iccv09Data/labels/6000091.regions.txt
# Processing iccv09Data/labels/6000203.regions.txt (48 negatives)
# Corrected iccv09Data/labels/6000203.regions.txt
# Processing iccv09Data/labels/1000929.regions.txt (1 negatives)
# Corrected iccv09Data/labels/1000929.regions.txt
# Processing iccv09Data/labels/6000040.regions.txt (3 negatives)
# Corrected iccv09Data/labels/6000040.regions.txt
# Deleted iccv09Data/labels/5000131.regions.txt (15.94% negatives)
# Processing iccv09Data/labels/6000159.regions.txt (11 negatives)
# Corrected iccv09Data/labels/6000159.regions.txt
# Deleted iccv09Data/labels/6000251.regions.txt (1.21% negatives)
# Deleted iccv09Data/labels/5000201.regions.txt (16.30% negatives)
# Processing iccv09Data/labels/6000317.regions.txt (8 negatives)
# Corrected iccv09Data/labels/6000317.regions.txt
# Processing iccv09Data/labels/9002474.regions.txt (20 negatives)
# Corrected iccv09Data/labels/9002474.regions.txt
# Processing iccv09Data/labels/6000331.regions.txt (207 negatives)
# Corrected iccv09Data/labels/6000331.regions.txt
# Processing iccv09Data/labels/6000080.regions.txt (7 negatives)
# Corrected iccv09Data/labels/6000080.regions.txt
# Processing iccv09Data/labels/6000188.regions.txt (138 negatives)
# Corrected iccv09Data/labels/6000188.regions.txt
# Processing iccv09Data/labels/6000272.regions.txt (34 negatives)
# Corrected iccv09Data/labels/6000272.regions.txt
# Processing iccv09Data/labels/6000073.regions.txt (4 negatives)
# Corrected iccv09Data/labels/6000073.regions.txt
# Processing iccv09Data/labels/0102436.regions.txt (22 negatives)
# Corrected iccv09Data/labels/0102436.regions.txt
# Processing iccv09Data/labels/6000042.regions.txt (19 negatives)
# Corrected iccv09Data/labels/6000042.regions.txt
# Processing iccv09Data/labels/6000302.regions.txt (30 negatives)
# Corrected iccv09Data/labels/6000302.regions.txt
# Processing iccv09Data/labels/2000028.regions.txt (1 negatives)
# Corrected iccv09Data/labels/2000028.regions.txt
# Processing iccv09Data/labels/6000084.regions.txt (83 negatives)
# Corrected iccv09Data/labels/6000084.regions.txt
# Processing iccv09Data/labels/6000041.regions.txt (27 negatives)
# Corrected iccv09Data/labels/6000041.regions.txt
# Processing iccv09Data/labels/6000140.regions.txt (60 negatives)
# Corrected iccv09Data/labels/6000140.regions.txt
# Processing iccv09Data/labels/6000085.regions.txt (8 negatives)
# Corrected iccv09Data/labels/6000085.regions.txt
# Processing iccv09Data/labels/5000188.regions.txt (43 negatives)
# Corrected iccv09Data/labels/5000188.regions.txt
# Processing iccv09Data/labels/6000239.regions.txt (4 negatives)
# Corrected iccv09Data/labels/6000239.regions.txt
# Processing iccv09Data/labels/6000168.regions.txt (68 negatives)
# Corrected iccv09Data/labels/6000168.regions.txt
# Processing iccv09Data/labels/5000137.regions.txt (4 negatives)
# Corrected iccv09Data/labels/5000137.regions.txt
# Processing iccv09Data/labels/6000077.regions.txt (61 negatives)
# Corrected iccv09Data/labels/6000077.regions.txt
# Deleted iccv09Data/labels/0103468.regions.txt (1.81% negatives)
# Processing iccv09Data/labels/6000304.regions.txt (1 negatives)
# Corrected iccv09Data/labels/6000304.regions.txt
# Processing iccv09Data/labels/3000469.regions.txt (15 negatives)
# Corrected iccv09Data/labels/3000469.regions.txt
# Processing iccv09Data/labels/6000018.regions.txt (83 negatives)
# Corrected iccv09Data/labels/6000018.regions.txt
# Processing iccv09Data/labels/6000337.regions.txt (88 negatives)
# Corrected iccv09Data/labels/6000337.regions.txt

# %%
# ensure no more unknown
import os
import re

# Directory containing the label files
label_dir = "iccv09Data/labels/"
negative_files = []

# Regex pattern to match various negative number formats
negative_pattern = re.compile(r'-\d*\.?\d+')  # Matches: -1, -123, -1.23, -.5

for filename in os.listdir(label_dir):
    if filename.endswith(".regions.txt"):
        filepath = os.path.join(label_dir, filename)
        with open(filepath, 'r') as f:
            content = f.read()
            
            # Find all negative numbers in file
            negatives = negative_pattern.findall(content)
            
            if negatives:
                print(f"\nFound {len(negatives)} negative value(s) in {filename}:")
                print("Negative values:", ", ".join(negatives))
                negative_files.append(filename)

print("\n=== Summary ===")
print(f"Total files with negative values: {len(negative_files)}")
if negative_files:
    print("Affected files:")
    for f in negative_files:
        print(f" - {f}")
else:
    print("No files contain negative values.")
# Out:
# === Summary ===
# Total files with negative values: 0
# No files contain negative values.

# %%
# drop the samples of unknown
import os

label_dir = "iccv09Data/labels/"

# Get all PNG files
png_files = [f for f in os.listdir(label_dir) if f.endswith('.png')]

for png in png_files:
    base_name = os.path.splitext(png)[0]  # Get filename without extension
    required_files = [
        f"{base_name}.layers.txt",
        f"{base_name}.regions.txt",
        f"{base_name}.surfaces.txt"
    ]
    
    # Check if all required files exist
    missing_files = [f for f in required_files if not os.path.exists(os.path.join(label_dir, f))]
    
    if missing_files:
        print(f"Deleting incomplete bundle for {base_name}:")
        print(f"  Missing files: {', '.join(missing_files)}")
        
        # Delete PNG
        png_path = os.path.join(label_dir, png)
        os.remove(png_path)
        print(f"  Deleted: {png}")
        
        # Delete any existing TXTs
        for txt in required_files:
            txt_path = os.path.join(label_dir, txt)
            if os.path.exists(txt_path):
                os.remove(txt_path)
                print(f"  Deleted: {txt}")
        
        print("  Bundle removed\n")

print("Cleanup complete")
# Out:
# Cleanup complete

# %%
# Let's take a look at the dataset
import mmcv
import mmengine
import matplotlib.pyplot as plt

img = mmcv.imread('iccv09Data/images/6000124.jpg')
plt.figure(figsize=(8, 6))
plt.imshow(mmcv.bgr2rgb(img))
plt.show()

# %% [markdown]
# We need to convert the annotation into semantic map format as an image.

# %%
# define dataset root and directory for images and annotations
data_root = 'iccv09Data'
img_dir = 'images'
ann_dir = 'labels'
# define class and palette for better visualization
classes = ('sky', 'tree', 'road', 'grass', 'water', 'bldg', 'mntn', 'fg obj')
palette = [[128, 128, 128], [129, 127, 38], [120, 69, 125], [53, 125, 34],
           [0, 11, 123], [118, 20, 12], [122, 81, 25], [241, 134, 51]]

# %%
import os.path as osp
import numpy as np
from PIL import Image

# convert dataset annotation to semantic segmentation map
for file in mmengine.scandir(osp.join(data_root, ann_dir), suffix='.regions.txt'):
  seg_map = np.loadtxt(osp.join(data_root, ann_dir, file)).astype(np.uint8)
  seg_img = Image.fromarray(seg_map).convert('P')
  seg_img.putpalette(np.array(palette, dtype=np.uint8))
  seg_img.save(osp.join(data_root, ann_dir, file.replace('.regions.txt',
                                                         '.png')))

# %%
# Let's take a look at the segmentation map we got
import matplotlib.patches as mpatches
img = Image.open('iccv09Data/labels/6000124.png')
plt.figure(figsize=(8, 6))
im = plt.imshow(np.array(img.convert('RGB')))

# create a patch (proxy artist) for every color
patches = [mpatches.Patch(color=np.array(palette[i])/255.,
                          label=classes[i]) for i in range(8)]
# put those patched as legend-handles into the legend
plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,
           fontsize='large')

plt.show()

# %% [markdown]
# # Prepare train/val split

# %%
# split train/val set randomly
split_dir = 'splits'
mmengine.mkdir_or_exist(osp.join(data_root, split_dir))
filename_list = [osp.splitext(filename)[0] for filename in mmengine.scandir(
    osp.join(data_root, ann_dir), suffix='.png')]
with open(osp.join(data_root, split_dir, 'train.txt'), 'w') as f:
  # select first 4/5 as train set
  train_length = int(len(filename_list)*4/5)
  f.writelines(line + '\n' for line in filename_list[:train_length])
with open(osp.join(data_root, split_dir, 'val.txt'), 'w') as f:
  # select last 1/5 as train set
  f.writelines(line + '\n' for line in filename_list[train_length:])

# %% [markdown]
# After downloading the data, we need to implement `load_annotations` function in the new dataset class `StanfordBackgroundDataset`.

# %%
from mmseg.registry import DATASETS
from mmseg.datasets import BaseSegDataset


@DATASETS.register_module()
class StanfordBackgroundDataset(BaseSegDataset):
  METAINFO = dict(classes = classes, palette = palette)
  def __init__(self, **kwargs):
    super().__init__(img_suffix='.jpg', seg_map_suffix='.png', **kwargs)

# %% [markdown]
# ### Create a config file
# In the next step, we need to modify the config for the training. To accelerate the process, we finetune the model from trained weights.

# %%
# there are plenty of models
# you may check what models are available on
# https://mmsegmentation.readthedocs.io/en/latest/modelzoo_statistics.html

# %%
# !mim download mmsegmentation --config pspnet_r50-d8_4xb2-40k_cityscapes-512x1024 --dest .
# Out:
# processing pspnet_r50-d8_4xb2-40k_cityscapes-512x1024...
# downloading ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.1/187.1 MiB 108.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Successfully downloaded pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth to /home/test/carasml/segmentation/PSPNet/mmsegmentation
# Successfully dumped pspnet_r50-d8_4xb2-40k_cityscapes-512x1024.py to /home/test/carasml/segmentation/PSPNet/mmsegmentation

# %% [markdown]
# The above code downloads weights of a pretrained model <br>
# if it was not successful  <br>
# go to terminal, and run:  <br>
# conda activate "your environment name"  <br>
# cd mmsegmentation  <br>
# mim download mmsegmentation --config pspnet_r50-d8_4xb2-40k_cityscapes-512x1024 --dest .

# %%
from mmengine import Config
cfg = Config.fromfile('configs/pspnet/pspnet_r50-d8_4xb2-40k_cityscapes-512x1024.py')
print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# crop_size = (
#     512,
#     1024,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         1024,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = 'data/cityscapes/'
# dataset_type = 'CityscapesDataset'
# default_hooks = dict(
#     checkpoint=dict(by_epoch=False, interval=4000, type='CheckpointHook'),
#     logger=dict(interval=50, log_metric_by_epoch=False, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# model = dict(
#     auxiliary_head=dict(
#         align_corners=False,
#         channels=256,
#         concat_input=False,
#         dropout_ratio=0.1,
#         in_channels=1024,
#         in_index=2,
#         loss_decode=dict(
#             loss_weight=0.4, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=19,
#         num_convs=1,
#         type='FCNHead'),
#     backbone=dict(
#         contract_dilation=True,
#         depth=50,
#         dilations=(
#             1,
#             1,
#             2,
#             4,
#         ),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         norm_eval=False,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         strides=(
#             1,
#             2,
#             1,
#             1,
#         ),
#         style='pytorch',
#         type='ResNetV1c'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             512,
#             1024,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=512,
#         dropout_ratio=0.1,
#         in_channels=2048,
#         in_index=3,
#         loss_decode=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=19,
#         pool_scales=(
#             1,
#             2,
#             3,
#             6,
#         ),
#         type='PSPHead'),
#     pretrained='open-mmlab://resnet50_v1c',
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     type='EncoderDecoder')
# norm_cfg = dict(requires_grad=True, type='SyncBN')
# optim_wrapper = dict(
#     clip_grad=None,
#     optimizer=dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005),
#     type='OptimWrapper')
# optimizer = dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005)
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=False,
#         end=40000,
#         eta_min=0.0001,
#         power=0.9,
#         type='PolyLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='leftImg8bit/val', seg_map_path='gtFine/val'),
#         data_root='data/cityscapes/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 2048,
#                 1024,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='CityscapesDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         2048,
#         1024,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(max_iters=40000, type='IterBasedTrainLoop', val_interval=4000)
# train_dataloader = dict(
#     batch_size=2,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='leftImg8bit/train', seg_map_path='gtFine/train'),
#         data_root='data/cityscapes/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     2048,
#                     1024,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     512,
#                     1024,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ],
#         type='CityscapesDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             2048,
#             1024,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         512,
#         1024,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=0.0, type='RandomFlip'),
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='leftImg8bit/val', seg_map_path='gtFine/val'),
#         data_root='data/cityscapes/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 2048,
#                 1024,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='CityscapesDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])

# %% [markdown]
# Since the given config is used to train PSPNet on the cityscapes dataset, we need to modify it accordingly for our new dataset.

# %%
# if we use only one GPU, BN is used instead of SyncBN
#cfg.norm_cfg = dict(type='BN', requires_grad=True)
cfg.crop_size = (256, 256)
cfg.model.data_preprocessor.size = cfg.crop_size
cfg.model.backbone.norm_cfg = cfg.norm_cfg
cfg.model.decode_head.norm_cfg = cfg.norm_cfg
cfg.model.auxiliary_head.norm_cfg = cfg.norm_cfg
# modify num classes of the model in decode/auxiliary head
cfg.model.decode_head.num_classes = 8
cfg.model.auxiliary_head.num_classes = 8

# Modify dataset type and path
cfg.dataset_type = 'StanfordBackgroundDataset'
cfg.data_root = data_root

cfg.train_dataloader.batch_size = 8

cfg.train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations'),
    dict(type='RandomResize', scale=(320, 240), ratio_range=(0.5, 2.0), keep_ratio=True),
    dict(type='RandomCrop', crop_size=cfg.crop_size, cat_max_ratio=0.75),
    dict(type='RandomFlip', prob=0.5),
    dict(type='PackSegInputs')
]

cfg.test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='Resize', scale=(320, 240), keep_ratio=True),
    # add loading annotation after ``Resize`` because ground truth
    # does not need to do resize data transform
    dict(type='LoadAnnotations'),
    dict(type='PackSegInputs')
]


cfg.train_dataloader.dataset.type = cfg.dataset_type
cfg.train_dataloader.dataset.data_root = cfg.data_root
cfg.train_dataloader.dataset.data_prefix = dict(img_path=img_dir, seg_map_path=ann_dir)
cfg.train_dataloader.dataset.pipeline = cfg.train_pipeline
cfg.train_dataloader.dataset.ann_file = 'splits/train.txt'

cfg.val_dataloader.dataset.type = cfg.dataset_type
cfg.val_dataloader.dataset.data_root = cfg.data_root
cfg.val_dataloader.dataset.data_prefix = dict(img_path=img_dir, seg_map_path=ann_dir)
cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
cfg.val_dataloader.dataset.ann_file = 'splits/val.txt'

cfg.test_dataloader = cfg.val_dataloader


# Load the pretrained weights
cfg.load_from = 'pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth'

# Set up working dir to save files and logs.
cfg.work_dir = './work_dirs/tutorial'

cfg.train_cfg.max_iters = 200
cfg.train_cfg.val_interval = 200
cfg.default_hooks.logger.interval = 10
cfg.default_hooks.checkpoint.interval = 200

cfg.optim_wrapper.optimizer.lr = 0.0001
cfg.optimizer.lr = 0.0001

# Set seed to facilitate reproducing the result
cfg['randomness'] = dict(seed=0)

# Let's have a look at the final config used for training
print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# crop_size = (
#     256,
#     256,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         1024,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = 'iccv09Data'
# dataset_type = 'StanfordBackgroundDataset'
# default_hooks = dict(
#     checkpoint=dict(by_epoch=False, interval=200, type='CheckpointHook'),
#     logger=dict(interval=10, log_metric_by_epoch=False, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# load_from = 'pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# model = dict(
#     auxiliary_head=dict(
#         align_corners=False,
#         channels=256,
#         concat_input=False,
#         dropout_ratio=0.1,
#         in_channels=1024,
#         in_index=2,
#         loss_decode=dict(
#             loss_weight=0.4, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=8,
#         num_convs=1,
#         type='FCNHead'),
#     backbone=dict(
#         contract_dilation=True,
#         depth=50,
#         dilations=(
#             1,
#             1,
#             2,
#             4,
#         ),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         norm_eval=False,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         strides=(
#             1,
#             2,
#             1,
#             1,
#         ),
#         style='pytorch',
#         type='ResNetV1c'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             256,
#             256,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=512,
#         dropout_ratio=0.1,
#         in_channels=2048,
#         in_index=3,
#         loss_decode=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=8,
#         pool_scales=(
#             1,
#             2,
#             3,
#             6,
#         ),
#         type='PSPHead'),
#     pretrained='open-mmlab://resnet50_v1c',
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     type='EncoderDecoder')
# norm_cfg = dict(requires_grad=True, type='SyncBN')
# optim_wrapper = dict(
#     clip_grad=None,
#     optimizer=dict(lr=0.0001, momentum=0.9, type='SGD', weight_decay=0.0005),
#     type='OptimWrapper')
# optimizer = dict(lr=0.0001, momentum=0.9, type='SGD', weight_decay=0.0005)
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=False,
#         end=40000,
#         eta_min=0.0001,
#         power=0.9,
#         type='PolyLR'),
# ]
# randomness = dict(seed=0)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/val.txt',
#         data_prefix=dict(img_path='images', seg_map_path='labels'),
#         data_root='iccv09Data',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 320,
#                 240,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         320,
#         240,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(max_iters=200, type='IterBasedTrainLoop', val_interval=200)
# train_dataloader = dict(
#     batch_size=8,
#     dataset=dict(
#         ann_file='splits/train.txt',
#         data_prefix=dict(img_path='images', seg_map_path='labels'),
#         data_root='iccv09Data',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     320,
#                     240,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     256,
#                     256,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             320,
#             240,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         256,
#         256,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=0.0, type='RandomFlip'),
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/val.txt',
#         data_prefix=dict(img_path='images', seg_map_path='labels'),
#         data_root='iccv09Data',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 320,
#                 240,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/tutorial'

# %% [markdown]
# ### Train and Evaluation

# %%
from mmengine.runner import Runner

runner = Runner.from_cfg(cfg)
# Out:
# 06/06 11:48:31 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.18 (main, Jun  5 2025, 13:14:17) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 0
#     GPU 0: NVIDIA GeForce RTX 5090
#     CUDA_HOME: /usr/local/cuda-12.8/
#     NVCC: Cuda compilation tools, release 12.8, V12.8.93
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.7.0+cu128
#     PyTorch compiling details: PyTorch built with:
#   - GCC 11.2
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2024.2-Product Build 20240605 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.7.1 (Git Hash 8d263e693366ef8db40acc569cc7d8edf644556d)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.8
#   - NVCC architecture flags: -gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90;-gencode;arch=compute_100,code=sm_100;-gencode;arch=compute_120,code=sm_120;-gencode;arch=compute_120,code=compute_120
#   - CuDNN 90.7.1
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, COMMIT_SHA=134179474539648ba7dee1317959529fbd0e7f89, CUDA_VERSION=12.8, CUDNN_VERSION=9.7.1, CXX_COMPILER=/opt/rh/gcc-toolset-11/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=1 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DLIBKINETO_NOXPUPTI=ON -DUSE_FBGEMM -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=range-loop-construct -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-unknown-pragmas -Wno-unused-parameter -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, TORCH_VERSION=2.7.0, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.22.0+cu128
#     OpenCV: 4.11.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/06 11:48:31 - mmengine - INFO - Config:
# crop_size = (
#     256,
#     256,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         1024,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = 'iccv09Data'
# dataset_type = 'StanfordBackgroundDataset'
# default_hooks = dict(
#     checkpoint=dict(by_epoch=False, interval=200, type='CheckpointHook'),
#     logger=dict(interval=10, log_metric_by_epoch=False, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# load_from = 'pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# model = dict(
#     auxiliary_head=dict(
#         align_corners=False,
#         channels=256,
#         concat_input=False,
#         dropout_ratio=0.1,
#         in_channels=1024,
#         in_index=2,
#         loss_decode=dict(
#             loss_weight=0.4, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=8,
#         num_convs=1,
#         type='FCNHead'),
#     backbone=dict(
#         contract_dilation=True,
#         depth=50,
#         dilations=(
#             1,
#             1,
#             2,
#             4,
#         ),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         norm_eval=False,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         strides=(
#             1,
#             2,
#             1,
#             1,
#         ),
#         style='pytorch',
#         type='ResNetV1c'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             256,
#             256,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=512,
#         dropout_ratio=0.1,
#         in_channels=2048,
#         in_index=3,
#         loss_decode=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=8,
#         pool_scales=(
#             1,
#             2,
#             3,
#             6,
#         ),
#         type='PSPHead'),
#     pretrained='open-mmlab://resnet50_v1c',
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     type='EncoderDecoder')
# norm_cfg = dict(requires_grad=True, type='SyncBN')
# optim_wrapper = dict(
#     clip_grad=None,
#     optimizer=dict(lr=0.0001, momentum=0.9, type='SGD', weight_decay=0.0005),
#     type='OptimWrapper')
# optimizer = dict(lr=0.0001, momentum=0.9, type='SGD', weight_decay=0.0005)
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=False,
#         end=40000,
#         eta_min=0.0001,
#         power=0.9,
#         type='PolyLR'),
# ]
# randomness = dict(seed=0)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/val.txt',
#         data_prefix=dict(img_path='images', seg_map_path='labels'),
#         data_root='iccv09Data',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 320,
#                 240,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         320,
#         240,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(max_iters=200, type='IterBasedTrainLoop', val_interval=200)
# train_dataloader = dict(
#     batch_size=8,
#     dataset=dict(
#         ann_file='splits/train.txt',
#         data_prefix=dict(img_path='images', seg_map_path='labels'),
#         data_root='iccv09Data',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     320,
#                     240,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     256,
#                     256,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             320,
#             240,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         256,
#         256,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=0.0, type='RandomFlip'),
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/val.txt',
#         data_prefix=dict(img_path='images', seg_map_path='labels'),
#         data_root='iccv09Data',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 320,
#                 240,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/tutorial'
# /home/test/carasml/segmentation/PSPNet/mmengine/mmengine/utils/manager.py:113: UserWarning: <class 'mmseg.visualization.local_visualizer.SegLocalVisualizer'> instance named of visualizer has been created, the method `get_instance` should not accept any other arguments
#   warnings.warn(
# /home/test/carasml/segmentation/PSPNet/mmsegmentation/mmseg/models/backbones/resnet.py:431: UserWarning: DeprecationWarning: pretrained is a deprecated, please use "init_cfg" instead
#   warnings.warn('DeprecationWarning: pretrained is a deprecated, '
# /home/test/carasml/segmentation/PSPNet/mmsegmentation/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /home/test/carasml/segmentation/PSPNet/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# 06/06 11:48:31 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/06 11:48:31 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /home/test/carasml/segmentation/PSPNet/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:60: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn('The draw is False, it means that the '

# %%
# start training
runner.train()
# Out:
# 06/06 11:49:02 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# 06/06 11:49:02 - mmengine - INFO - load model from: open-mmlab://resnet50_v1c
# 06/06 11:49:02 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://resnet50_v1c
# 06/06 11:49:02 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# Loads checkpoint by local backend from path: pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for decode_head.conv_seg.weight: copying a param with shape torch.Size([19, 512, 1, 1]) from checkpoint, the shape in current model is torch.Size([8, 512, 1, 1]).
# size mismatch for decode_head.conv_seg.bias: copying a param with shape torch.Size([19]) from checkpoint, the shape in current model is torch.Size([8]).
# size mismatch for auxiliary_head.conv_seg.weight: copying a param with shape torch.Size([19, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([8, 256, 1, 1]).
# size mismatch for auxiliary_head.conv_seg.bias: copying a param with shape torch.Size([19]) from checkpoint, the shape in current model is torch.Size([8]).
# 06/06 11:49:03 - mmengine - INFO - Load checkpoint from pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth
# 06/06 11:49:03 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 06/06 11:49:03 - mmengine - INFO - Checkpoints will be saved to /home/test/carasml/segmentation/PSPNet/mmsegmentation/work_dirs/tutorial.
# 06/06 11:49:03 - mmengine - INFO - Iter(train) [ 10/200]  lr: 1.0000e-04  eta: 0:00:09  time: 0.0504  data_time: 0.0036  memory: 3916  loss: 2.5936  decode.loss_ce: 1.8531  decode.acc_seg: 12.9021  aux.loss_ce: 0.7405  aux.acc_seg: 7.4567
# 06/06 11:49:04 - mmengine - INFO - Iter(train) [ 20/200]  lr: 1.0000e-04  eta: 0:00:08  time: 0.0492  data_time: 0.0034  memory: 3916  loss: 2.4957  decode.loss_ce: 1.7806  decode.acc_seg: 10.8179  aux.loss_ce: 0.7150  aux.acc_seg: 8.7110
# 06/06 11:49:04 - mmengine - INFO - Iter(train) [ 30/200]  lr: 1.0000e-04  eta: 0:00:08  time: 0.0492  data_time: 0.0035  memory: 3916  loss: 2.4738  decode.loss_ce: 1.7607  decode.acc_seg: 11.3030  aux.loss_ce: 0.7131  aux.acc_seg: 12.1345
# 06/06 11:49:05 - mmengine - INFO - Iter(train) [ 40/200]  lr: 1.0000e-04  eta: 0:00:07  time: 0.0501  data_time: 0.0034  memory: 3916  loss: 2.5760  decode.loss_ce: 1.8273  decode.acc_seg: 34.2949  aux.loss_ce: 0.7487  aux.acc_seg: 9.4627
# 06/06 11:49:05 - mmengine - INFO - Iter(train) [ 50/200]  lr: 1.0000e-04  eta: 0:00:07  time: 0.0504  data_time: 0.0034  memory: 3916  loss: 2.4192  decode.loss_ce: 1.7139  decode.acc_seg: 27.9440  aux.loss_ce: 0.7053  aux.acc_seg: 18.6418
# 06/06 11:49:06 - mmengine - INFO - Iter(train) [ 60/200]  lr: 1.0000e-04  eta: 0:00:06  time: 0.0494  data_time: 0.0034  memory: 3916  loss: 2.3993  decode.loss_ce: 1.6938  decode.acc_seg: 45.8661  aux.loss_ce: 0.7055  aux.acc_seg: 19.2273
# 06/06 11:49:06 - mmengine - INFO - Exp name: pspnet_r50-d8_4xb2-40k_cityscapes-512x1024_20250606_114831
# 06/06 11:49:06 - mmengine - INFO - Iter(train) [ 70/200]  lr: 1.0000e-04  eta: 0:00:06  time: 0.0503  data_time: 0.0035  memory: 3916  loss: 2.4258  decode.loss_ce: 1.7070  decode.acc_seg: 59.2406  aux.loss_ce: 0.7188  aux.acc_seg: 20.3700
# 06/06 11:49:07 - mmengine - INFO - Iter(train) [ 80/200]  lr: 1.0000e-04  eta: 0:00:05  time: 0.0495  data_time: 0.0035  memory: 3916  loss: 2.4279  decode.loss_ce: 1.7046  decode.acc_seg: 61.1934  aux.loss_ce: 0.7233  aux.acc_seg: 19.0104
# 06/06 11:49:07 - mmengine - INFO - Iter(train) [ 90/200]  lr: 1.0000e-04  eta: 0:00:05  time: 0.0491  data_time: 0.0034  memory: 3916  loss: 2.3692  decode.loss_ce: 1.6600  decode.acc_seg: 65.8649  aux.loss_ce: 0.7092  aux.acc_seg: 35.9125
# 06/06 11:49:08 - mmengine - INFO - Iter(train) [100/200]  lr: 1.0000e-04  eta: 0:00:04  time: 0.0492  data_time: 0.0034  memory: 3916  loss: 2.2813  decode.loss_ce: 1.5967  decode.acc_seg: 45.8690  aux.loss_ce: 0.6846  aux.acc_seg: 35.1562
# 06/06 11:49:08 - mmengine - INFO - Iter(train) [110/200]  lr: 1.0000e-04  eta: 0:00:04  time: 0.0492  data_time: 0.0034  memory: 3916  loss: 2.2724  decode.loss_ce: 1.5884  decode.acc_seg: 60.8264  aux.loss_ce: 0.6840  aux.acc_seg: 40.4893
# 06/06 11:49:08 - mmengine - INFO - Iter(train) [120/200]  lr: 1.0000e-04  eta: 0:00:03  time: 0.0501  data_time: 0.0036  memory: 3916  loss: 2.3222  decode.loss_ce: 1.6152  decode.acc_seg: 56.5776  aux.loss_ce: 0.7070  aux.acc_seg: 43.1768
# 06/06 11:49:09 - mmengine - INFO - Iter(train) [130/200]  lr: 1.0000e-04  eta: 0:00:03  time: 0.0492  data_time: 0.0034  memory: 3916  loss: 2.2632  decode.loss_ce: 1.5744  decode.acc_seg: 50.7571  aux.loss_ce: 0.6888  aux.acc_seg: 41.1512
# 06/06 11:49:09 - mmengine - INFO - Iter(train) [140/200]  lr: 1.0000e-04  eta: 0:00:02  time: 0.0509  data_time: 0.0036  memory: 3916  loss: 2.3217  decode.loss_ce: 1.6107  decode.acc_seg: 73.6998  aux.loss_ce: 0.7110  aux.acc_seg: 61.8708
# 06/06 11:49:10 - mmengine - INFO - Iter(train) [150/200]  lr: 1.0000e-04  eta: 0:00:02  time: 0.0493  data_time: 0.0035  memory: 3916  loss: 2.3314  decode.loss_ce: 1.6045  decode.acc_seg: 69.2653  aux.loss_ce: 0.7269  aux.acc_seg: 60.8379
# 06/06 11:49:10 - mmengine - INFO - Iter(train) [160/200]  lr: 1.0000e-04  eta: 0:00:01  time: 0.0502  data_time: 0.0034  memory: 3916  loss: 2.2297  decode.loss_ce: 1.5425  decode.acc_seg: 68.4072  aux.loss_ce: 0.6872  aux.acc_seg: 60.5458
# 06/06 11:49:11 - mmengine - INFO - Iter(train) [170/200]  lr: 1.0000e-04  eta: 0:00:01  time: 0.0493  data_time: 0.0035  memory: 3916  loss: 2.2359  decode.loss_ce: 1.5349  decode.acc_seg: 63.9102  aux.loss_ce: 0.7010  aux.acc_seg: 55.6260
# 06/06 11:49:11 - mmengine - INFO - Iter(train) [180/200]  lr: 1.0000e-04  eta: 0:00:00  time: 0.0493  data_time: 0.0035  memory: 3916  loss: 2.1595  decode.loss_ce: 1.4866  decode.acc_seg: 61.1191  aux.loss_ce: 0.6730  aux.acc_seg: 61.5554
# 06/06 11:49:12 - mmengine - INFO - Iter(train) [190/200]  lr: 1.0000e-04  eta: 0:00:00  time: 0.0500  data_time: 0.0034  memory: 3916  loss: 1.9854  decode.loss_ce: 1.3628  decode.acc_seg: 57.3793  aux.loss_ce: 0.6227  aux.acc_seg: 51.8972
# 06/06 11:49:12 - mmengine - INFO - Iter(train) [200/200]  lr: 1.0000e-04  eta: 0:00:00  time: 0.0494  data_time: 0.0035  memory: 3916  loss: 2.1799  decode.loss_ce: 1.4857  decode.acc_seg: 68.1763  aux.loss_ce: 0.6942  aux.acc_seg: 62.0973
# 06/06 11:49:12 - mmengine - INFO - Saving checkpoint at 200 iterations
# 06/06 11:49:13 - mmengine - INFO - Iter(val) [ 10/134]    eta: 0:00:02  time: 0.0204  data_time: 0.0160  memory: 1087
# 06/06 11:49:14 - mmengine - INFO - Iter(val) [ 20/134]    eta: 0:00:01  time: 0.0047  data_time: 0.0008  memory: 1087
# 06/06 11:49:14 - mmengine - INFO - Iter(val) [ 30/134]    eta: 0:00:01  time: 0.0046  data_time: 0.0007  memory: 1087
# 06/06 11:49:14 - mmengine - INFO - Iter(val) [ 40/134]    eta: 0:00:00  time: 0.0046  data_time: 0.0007  memory: 1087
# 06/06 11:49:14 - mmengine - INFO - Iter(val) [ 50/134]    eta: 0:00:00  time: 0.0046  data_time: 0.0007  memory: 1087
# 06/06 11:49:14 - mmengine - INFO - Iter(val) [ 60/134]    eta: 0:00:00  time: 0.0048  data_time: 0.0007  memory: 1087
# 06/06 11:49:14 - mmengine - INFO - Iter(val) [ 70/134]    eta: 0:00:00  time: 0.0047  data_time: 0.0007  memory: 1087
# 06/06 11:49:14 - mmengine - INFO - Iter(val) [ 80/134]    eta: 0:00:00  time: 0.0047  data_time: 0.0007  memory: 1087
# 06/06 11:49:14 - mmengine - INFO - Iter(val) [ 90/134]    eta: 0:00:00  time: 0.0046  data_time: 0.0007  memory: 1087
# 06/06 11:49:14 - mmengine - INFO - Iter(val) [100/134]    eta: 0:00:00  time: 0.0046  data_time: 0.0007  memory: 1087
# 06/06 11:49:14 - mmengine - INFO - Iter(val) [110/134]    eta: 0:00:00  time: 0.0046  data_time: 0.0007  memory: 1087
# 06/06 11:49:14 - mmengine - INFO - Iter(val) [120/134]    eta: 0:00:00  time: 0.0046  data_time: 0.0007  memory: 1087
# 06/06 11:49:14 - mmengine - INFO - Iter(val) [130/134]    eta: 0:00:00  time: 0.0045  data_time: 0.0007  memory: 1087
# 06/06 11:49:14 - mmengine - INFO - per class results:
# 06/06 11:49:14 - mmengine - INFO -
# +--------+-------+-------+
# | Class  |  IoU  |  Acc  |
# +--------+-------+-------+
# |  sky   | 73.67 | 76.96 |
# |  tree  |  57.3 | 70.31 |
# |  road  | 74.75 |  93.8 |
# | grass  |  0.0  |  0.0  |
# | water  |  0.0  |  0.0  |
# |  bldg  | 65.93 | 96.44 |
# |  mntn  |  0.0  |  0.0  |
# | fg obj | 52.12 | 63.81 |
# +--------+-------+-------+
# 06/06 11:49:14 - mmengine - INFO - Iter(val) [134/134]    aAcc: 75.6800  mIoU: 40.4700  mAcc: 50.1600  data_time: 0.0019  time: 0.0058
# EncoderDecoder(
#   (data_preprocessor): SegDataPreProcessor()
#   (backbone): ResNetV1c(
#     (stem): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): _BatchNormXd(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): _BatchNormXd(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (7): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU(inplace=True)
#     )
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): _BatchNormXd(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'open-mmlab://resnet50_v1c'}
#   (decode_head): PSPHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss(avg_non_ignore=False)
#     (conv_seg): Conv2d(512, 8, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (psp_modules): PPM(
#       (0): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=2)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=3)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (3): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=6)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#     )
#     (bottleneck): ConvModule(
#       (conv): Conv2d(4096, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate): ReLU(inplace=True)
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
#   (auxiliary_head): FCNHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss(avg_non_ignore=False)
#     (conv_seg): Conv2d(256, 8, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (convs): Sequential(
#       (0): ConvModule(
#         (conv): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# )

# %%
import torch
#after training/testing, clear cache
torch.cuda.empty_cache()
torch.cuda.synchronize()

# %% [markdown]
# Inference with trained model

# %%
from mmseg.apis import init_model, inference_model, show_result_pyplot

# Init the model from the config and the checkpoint
checkpoint_path = './work_dirs/tutorial/iter_200.pth'
model = init_model(cfg, checkpoint_path, 'cuda:0')

img = mmcv.imread('iccv09Data/images/6000124.jpg')
result = inference_model(model, img)
plt.figure(figsize=(8, 6))
vis_result = show_result_pyplot(model, img, result)
plt.imshow(mmcv.bgr2rgb(vis_result))
# Out:
# /home/test/carasml/segmentation/PSPNet/mmsegmentation/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /home/test/carasml/segmentation/PSPNet/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by local backend from path: ./work_dirs/tutorial/iter_200.pth
# /home/test/carasml/segmentation/PSPNet/mmengine/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
